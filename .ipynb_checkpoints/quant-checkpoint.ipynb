# %%
pip install jupyterlab-git
# Out:
# Requirement already satisfied: jupyterlab-git in /opt/python/lib/python3.13/site-packages (0.52.0)
# Requirement already satisfied: jupyter-server<3,>=2.0.1 in /opt/python/lib/python3.13/site-packages (from jupyterlab-git) (2.17.0)
# Requirement already satisfied: nbdime~=4.0.1 in /opt/python/lib/python3.13/site-packages (from jupyterlab-git) (4.0.4)
# Requirement already satisfied: nbformat in /opt/python/lib/python3.13/site-packages (from jupyterlab-git) (5.10.4)
# Requirement already satisfied: packaging in /opt/python/lib/python3.13/site-packages (from jupyterlab-git) (26.0)
# Requirement already satisfied: pexpect in /opt/python/lib/python3.13/site-packages (from jupyterlab-git) (4.9.0)
# Requirement already satisfied: traitlets~=5.0 in /opt/python/lib/python3.13/site-packages (from jupyterlab-git) (5.14.3)
# Requirement already satisfied: anyio>=3.1.0 in /opt/python/lib/python3.13/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (4.13.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/python/lib/python3.13/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (25.1.0)
# Requirement already satisfied: jinja2>=3.0.3 in /opt/python/lib/python3.13/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (3.1.6)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/python/lib/python3.13/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (8.8.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/python/lib/python3.13/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in /opt/python/lib/python3.13/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/python/lib/python3.13/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/python/lib/python3.13/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (7.17.1)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/python/lib/python3.13/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (0.25.0)
# Requirement already satisfied: pyzmq>=24 in /opt/python/lib/python3.13/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/python/lib/python3.13/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/python/lib/python3.13/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (0.18.1)
# Requirement already satisfied: tornado>=6.2.0 in /opt/python/lib/python3.13/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (6.5.5)
# Requirement already satisfied: websocket-client>=1.7 in /opt/python/lib/python3.13/site-packages (from jupyter-server<3,>=2.0.1->jupyterlab-git) (1.9.0)
# Requirement already satisfied: colorama in /opt/python/lib/python3.13/site-packages (from nbdime~=4.0.1->jupyterlab-git) (0.4.6)
# Requirement already satisfied: gitpython!=2.1.4,!=2.1.5,!=2.1.6 in /opt/python/lib/python3.13/site-packages (from nbdime~=4.0.1->jupyterlab-git) (3.1.46)
# Requirement already satisfied: pygments in /opt/python/lib/python3.13/site-packages (from nbdime~=4.0.1->jupyterlab-git) (2.20.0)
# Requirement already satisfied: requests in /opt/python/lib/python3.13/site-packages (from nbdime~=4.0.1->jupyterlab-git) (2.33.1)
# Requirement already satisfied: idna>=2.8 in /opt/python/lib/python3.13/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.11)
# Requirement already satisfied: argon2-cffi-bindings in /opt/python/lib/python3.13/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab-git) (25.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/python/lib/python3.13/site-packages (from gitpython!=2.1.4,!=2.1.5,!=2.1.6->nbdime~=4.0.1->jupyterlab-git) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/python/lib/python3.13/site-packages (from gitdb<5,>=4.0.1->gitpython!=2.1.4,!=2.1.5,!=2.1.6->nbdime~=4.0.1->jupyterlab-git) (5.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/python/lib/python3.13/site-packages (from jinja2>=3.0.3->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/python/lib/python3.13/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in /opt/python/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/python/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.26.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/python/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.1.0)
# Requirement already satisfied: pyyaml>=5.3 in /opt/python/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (6.0.3)
# Requirement already satisfied: referencing in /opt/python/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.37.0)
# Requirement already satisfied: rfc3339-validator in /opt/python/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/python/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.1.1)
# Requirement already satisfied: attrs>=22.2.0 in /opt/python/lib/python3.13/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/python/lib/python3.13/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.25.0 in /opt/python/lib/python3.13/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.30.0)
# Requirement already satisfied: fqdn in /opt/python/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.5.1)
# Requirement already satisfied: isoduration in /opt/python/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/python/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /opt/python/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.1.0)
# Requirement already satisfied: uri-template in /opt/python/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/python/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /opt/python/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.14.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/python/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (6.3.0)
# Requirement already satisfied: defusedxml in /opt/python/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/python/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/python/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/python/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/python/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.5.1)
# Requirement already satisfied: webencodings in /opt/python/lib/python3.13/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /opt/python/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/python/lib/python3.13/site-packages (from nbformat->jupyterlab-git) (2.21.2)
# Requirement already satisfied: six>=1.5 in /opt/python/lib/python3.13/site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.17.0)
# Requirement already satisfied: lark>=1.2.2 in /opt/python/lib/python3.13/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.3.1)
# Requirement already satisfied: ptyprocess in /opt/python/lib/python3.13/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.0.1->jupyterlab-git) (0.7.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/python/lib/python3.13/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab-git) (2.0.0)
# Requirement already satisfied: pycparser in /opt/python/lib/python3.13/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.0.1->jupyterlab-git) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/python/lib/python3.13/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/python/lib/python3.13/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.0.1->jupyterlab-git) (4.15.0)
# Requirement already satisfied: arrow>=0.15.0 in /opt/python/lib/python3.13/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (1.4.0)
# Requirement already satisfied: tzdata in /opt/python/lib/python3.13/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.0.1->jupyterlab-git) (2026.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/python/lib/python3.13/site-packages (from requests->nbdime~=4.0.1->jupyterlab-git) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/python/lib/python3.13/site-packages (from requests->nbdime~=4.0.1->jupyterlab-git) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/python/lib/python3.13/site-packages (from requests->nbdime~=4.0.1->jupyterlab-git) (2026.2.25)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install yfinance
# Out:
# Collecting yfinance
#   Downloading yfinance-1.2.2-py2.py3-none-any.whl.metadata (6.1 kB)
# Requirement already satisfied: pandas>=1.3.0 in /opt/python/lib/python3.13/site-packages (from yfinance) (2.3.3)
# Requirement already satisfied: numpy>=1.16.5 in /opt/python/lib/python3.13/site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: requests>=2.31 in /opt/python/lib/python3.13/site-packages (from yfinance) (2.33.1)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.12.tar.gz (19 kB)
#   Installing build dependencies ... -
# \
# |
# done
#   Getting requirements to build wheel ... -
# done
#   Preparing metadata (pyproject.toml) ... -
# done
# Requirement already satisfied: platformdirs>=2.0.0 in /opt/python/lib/python3.13/site-packages (from yfinance) (4.9.6)
# Requirement already satisfied: pytz>=2022.5 in /opt/python/lib/python3.13/site-packages (from yfinance) (2026.1.post1)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.4.7-py3-none-any.whl.metadata (23 kB)
# Collecting peewee>=3.16.2 (from yfinance)
#   Downloading peewee-4.0.4-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /opt/python/lib/python3.13/site-packages (from yfinance) (4.14.3)
# Collecting curl_cffi>=0.15 (from yfinance)
#   Downloading curl_cffi-0.15.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: protobuf>=3.19.0 in /opt/python/lib/python3.13/site-packages (from yfinance) (6.33.6)
# Requirement already satisfied: websockets>=13.0 in /opt/python/lib/python3.13/site-packages (from yfinance) (16.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /opt/python/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/python/lib/python3.13/site-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in /opt/python/lib/python3.13/site-packages (from curl_cffi>=0.15->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /opt/python/lib/python3.13/site-packages (from curl_cffi>=0.15->yfinance) (2026.2.25)
# Requirement already satisfied: rich in /opt/python/lib/python3.13/site-packages (from curl_cffi>=0.15->yfinance) (15.0.0)
# Requirement already satisfied: pycparser in /opt/python/lib/python3.13/site-packages (from cffi>=2.0.0->curl_cffi>=0.15->yfinance) (3.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/python/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /opt/python/lib/python3.13/site-packages (from pandas>=1.3.0->yfinance) (2026.1)
# Requirement already satisfied: six>=1.5 in /opt/python/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/python/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /opt/python/lib/python3.13/site-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/python/lib/python3.13/site-packages (from requests>=2.31->yfinance) (2.6.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/python/lib/python3.13/site-packages (from rich->curl_cffi>=0.15->yfinance) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/python/lib/python3.13/site-packages (from rich->curl_cffi>=0.15->yfinance) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/python/lib/python3.13/site-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.15->yfinance) (0.1.2)
# Downloading yfinance-1.2.2-py2.py3-none-any.whl (130 kB)
# Downloading curl_cffi-0.15.0-cp310-abi3-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/11.1 MB ? eta -:--:--
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 58.1 MB/s  0:00:00
# Downloading frozendict-2.4.7-py3-none-any.whl (16 kB)
# Downloading peewee-4.0.4-py3-none-any.whl (144 kB)
# Building wheels for collected packages: multitasking
#   Building wheel for multitasking (pyproject.toml) ... -
# done
#   Created wheel for multitasking: filename=multitasking-0.0.12-py3-none-any.whl size=15635 sha256=ecd5a79acc3832bc9e60ee1dc7e28d50c00afc26dc3150dfceea5e63e4ca9bb7
#   Stored in directory: /home/onyxia/.cache/pip/wheels/1e/df/0f/e2bbb22d689b30c681feb5410ab64a2523437b34c8ecfc6476
# Successfully built multitasking
# Installing collected packages: peewee, multitasking, frozendict, curl_cffi, yfinance
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0/5 [peewee]
#    ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━ 3/5 [curl_cffi]
#    ━━━━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━ 3/5 [curl_cffi]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5/5 [yfinance]
# Successfully installed curl_cffi-0.15.0 frozendict-2.4.7 multitasking-0.0.12 peewee-4.0.4 yfinance-1.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
tickers = ["GDX", "GOAU"]
prices = yf.download(tickers, start="2017-01-01", end="2023-01-01").dropna()
# Out:
# [                       0%                       ]
# [*********************100%***********************]  2 of 2 completed

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/python/lib/python3.13/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/python/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /opt/python/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/python/lib/python3.13/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/python/lib/python3.13/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /opt/python/lib/python3.13/site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/python/lib/python3.13/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /opt/python/lib/python3.13/site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in /opt/python/lib/python3.13/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/python/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/python/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

ax1.plot(prices['Close']['GDX'], color='blueviolet', label='VanEck Gold Miners')
ax1.set_xlabel("Date")
ax1.set_ylabel("Prices")
ax1.tick_params(axis='y', labelcolor='blueviolet')
ax1.legend(loc='upper left')

ax2 = ax1.twinx()

ax2.plot(prices['Close']['GOAU'], color='orangered', label='US Global GO GOLD and Precious Metal Miners ETF')
ax2.set_ylabel("Prices", color='orangered')
ax2.tick_params(axis='y', labelcolor='orangered')
ax2.legend(loc='upper right')

plt.title("GDX Vs Gold futures")
# Out:
# Text(0.5, 1.0, 'GDX Vs Gold futures')

# %%
X = add_constant(prices['Close']['GOAU'])
y = prices['Close']['GDX']
